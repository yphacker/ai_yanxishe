# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/eval.csv')
df.head()
# Out:
#            text    labels pred_labels
# 0   晕死 老人家 这么 老  negative    negative
# 1      有着 崇高 智慧  positive    positive
# 2     小三看 就 来 气  negative    negative
# 3         这小 畜生  negative    negative
# 4  可是 问 又 说 不 懂  negative    negative

# %%
error = df[df['labels'] != df['pred_labels']]

# %%
error.shape
# Out:
# (1599, 3)

# %%
error.head(50)
# Out:
#                                    text    labels pred_labels
# 32             那 又 不 说 可以 聊 多久 还 叫 自己 看  negative    positive
# 92                    想 安慰 安慰 就 会 说 风凉话  negative    positive
# 98                              失灵 好看 不  positive    negative
# 119                        一点 都 不 知道 谦虚  negative    positive
# 122                         我素 迷离 准备 歌曲  negative    positive
# 132   混得 不 好 入党 那 等 会 手机 数码 内燃机 可 大 马大哈  positive    negative
# 137                           勇敢 大胆 不要脸  negative    positive
# 139                         本人 现在 心情 很糟  positive    negative
# 144                为什么 什么 认识 说 英语 补考 不过  negative    positive
# 185                              傻妞好 漂亮  positive    negative
# 250                      谁 他 抠 钱 还 养小三俩  negative    positive
# 255                                眉来眼去  negative    positive
# 297                           赖皮 明明 比 帅  negative    positive
# 298                               臭蛋 晴天  positive    negative
# ...
